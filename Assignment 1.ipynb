# %%
# 1. Print a statement 

print("Hello! My name is Gautam Akshit and my hobby is RTI Activism and Publice Administration.")
# Out:
# Hello! My name is Gautam Akshit and my hobby is RTI Activism and Publice Administration.

# %%
# 2. Print comments
#This is a single-line comment
print("Comments are used to explain code. ") 
"""
This is a 
multi line comment 
"""
print("Multi-line comment example.")
# Out:
# Comments are used to explain code.
# Multi-line comment example.

# %%
# 3. Display Integar , Float , String , Boolean

integer_num = 10
float_num = 10.5
string_text = "python"
boolean_value = True

print("Integer:", integer_num) 
print("Float:" ,float_num) 
print("String:" ,string_text)
print("boolean:" , boolean_value)
# Out:
# Integer: 10
# Float: 10.5
# String: python
# boolean: True

# %%
# 4. type Conversions 
#Float to Integer
f = 15.75
print("Float to Integer:", int(f)) 

#String to Integer
s = "25" 
print("String to Integer:", int(s)) 

#Boolean to Integer

b = True 
print("Boolean to Integer:", int(b))
# Out:
# Float to Integer: 15
# String to Integer: 25
# Boolean to Integer: 1

# %%
# 5. Simple calculator operations 

a = 20 
b = 5

print("Addition:", a + b) 
print("Subtraction:" ,a - b) 
print( "Multiplication: " , a*b)
print("Division:" , a/b)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication:  100
# Division: 4.0

# %%
# 6. Expression to calculate hours in 1600 minutes

minutes = 160
hours = minutes/60

print("Hours in 160 minutes:", hours)
# Out:
# Hours in 160 minutes: 2.6666666666666665
