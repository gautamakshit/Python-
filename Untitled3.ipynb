# %%
# Part A - Dictionaries

# 1. Create an empty dictionary 

inventory = {}

#2. First product details 

product1 = {
    "Product Name" : "Mobile Phone",
    "Product Quantity": 5,
    "Product Price" : 20000,
    "Release Year" : 2020
}

# 3. Add deatils in inventory

inventory["ProductNo1"] = product1

# 4. Second product deatils 

product2 = {
    "Product Name" : "Laptop",
    "Product Quantity" : 3,
    "Product Price" : 50000,
    "Release Year" : 2022
}

# 5. Add second product in inventory

inventory["ProductNo2"] =product2

# 6. Display products in inventory 

print("Inventory:")
print(inventory)

# 7. Check release year in inventory

print("\nRelease Year of ProductNo1:",
inventory["ProductNo1"] ["Release Year"])

print("Release Year of ProductNo2:",
inventory["ProductNo2"] ["Release Year"])

# 8. Delete release year from both products 

del inventory["ProductNo1"]
["Release Year"]
del inventory["ProductNo2"]
["Release Year"]

print("\nInventory after deleting Release Year:")
print(inventory)

# Part B- Tuples

prices = (250, 300, 150, 400, 100, 350, 200)

# Highest and Lowest price

print("\nHIGHEST pRICE:",
max(prices))
print("Lowest Price:",
min(prices))

#Total sum

print("Total Sum:",sum(prices))

#Convert tuple into sorted list

sorted_prices = sorted(prices)
print("Sorted List:",
sorted_prices)

#Try to modify tuple 

try:
    prices[0] = 500
except TypeError as e:
    print("\nError:",e)
    print("Tuples are immutable and cannot be modified.")
# Out:
# Inventory:
# {'ProductNo1': {'Product Name': 'Mobile Phone', 'Product Quantity': 5, 'Product Price': 20000, 'Release Year': 2020}, 'ProductNo2': {'Product Name': 'Laptop', 'Product Quantity': 3, 'Product Price': 50000, 'Release Year': 2022}}
#
# Release Year of ProductNo1: 2020
# Release Year of ProductNo2: 2022
#
# Inventory after deleting Release Year:
# {}
#
# HIGHEST pRICE: 400
# Lowest Price: 100
# Total Sum: 1750
# Sorted List: [100, 150, 200, 250, 300, 350, 400]
#
# Error: 'tuple' object does not support item assignment
# Tuples are immutable and cannot be modified.
